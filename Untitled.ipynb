# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def compute_cost_linear_regression(X, y, w, b, lambda_l=1):
    '''
    Description: computes the cost for regularized linear regression
    ( the term with the numerator lambda helps to minimize the size of the parameters 
    (w1, w2,...),
    but I use the version where b is not regularized )
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: total_cost - real number - the cost of our calculations, which will help
    later to build a better model
    '''
    m = X.shape[0] # number of input data examples
    n = X.shape[1] # number of features of each example

    cost = 0
    for i in range(m):
       f_wb = np.dot(X[i],w)+b # the formula of linear regression model
       cost+= (f_wb-y[i])**2 
    cost = cost/(2*m)    # until here, we just applied the formula of the cost without regularization

    # the regularization part
    cost_r = 0
    for j in range(n):
        cost_r+= w[j]**2
    cost_r = (lambda_l/(2*m))* cost_r

    # adding the 2 costs
    total_cost = cost + cost_r
    return total_cost

# %%
# EXAMPLES PART - DOES NOT AFFECT OUR FINAL MODEL

np.random.seed(1) #running the cost function for some random input data (10 examples with 5 features each)
X1 = np.random.rand(10,5) 
y1 = np.array([0,1,0,0,1,1,1,1,0,1])
w1 = np.random.rand(5) - 0.5 
print(w1)
b1 = 0.5
lambda1 = 0.7
cost1 = compute_cost_linear_regression(X1, y1, w1, b1, lambda1)

print("Regularized cost example1:", cost1)


np.random.seed(1)  
X2 = np.random.rand(4,3) 
y2 = np.array([0,1,0,0])
w2 = np.random.rand(3) - 0.5
print(w2)
b2 = 0.5
lambda2 = 0.7
cost2 = compute_cost_linear_regression(X2, y2, w2, b2, lambda2)

print("Regularized cost example2:", cost2)
# Out:
# [-0.48063304  0.17883553 -0.28837188 -0.23445334 -0.00842684]
# Regularized cost example1: 0.236003117924045
# [-0.29554775  0.37811744 -0.47261241]
# Regularized cost example2: 0.1567201382524095

# %%
for i in range (X1.shape[1]):
    plt.scatter(X1[i,0], y1[i], marker='x', color='red') # use a scatter plot to display the data considering only the first feature of each example
#add a title & set x and y label
plt.title("Input vs Target")
plt.xlabel("input data")
plt.ylabel("target values")
plt.show()
# EXAMPLES PART - DOES NOT AFFECT OUR FINAL MODEL

# %%
def compute_gradient(X, y, w, b, lambda_l=1):
    '''
    Description: computes the partial derivative of the w vector and b scalar used in the gradient descent algorithm 
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: dj_dw - n array (size of w) and dj_db - scalar
    '''
    m = X.shape[0]
    n = X.shape[1]

    dj_dw = np.zeros((n,)) # null vector of n size
    dj_db = 0
    
    for i in range(m):
        f_wb = np.dot(X[i],w)+b
        aux = (f_wb - y[i])
        dj_db += aux # forming the derivative of b 

        # forming the gradient of w - unregularized part for now
        for j in range(n):
            dj_dw[j] += aux* X[i,j]

    dj_dw /= m
    dj_db /= m

    #now add the regularization part for the w feature vector
    for j in range(n):
        dj_dw[j] += (lambda_l/m) * w[j]

    return dj_db, dj_dw

# %%
# this is where HOTEL RENT PREDICTION MODEL data is taken as input

'''
We have 20 room rent examples with price per person/ night in Cluj-Napoca                         - OUTPUT
Each room has 4 features:                                          
 - number of stars on reviews : 0-10                                                               - INPUT
 - distance from the city center (meters)
 - room area (meters^2)
 '''

X = np.array([[6.8,1900,17],
              [8.4,1900,16],
              [8.4,1900,20],
              [8.7,2300,30],
              [8.7,2300,36],
              [8.6,2300,20],
              [7.1,1400,16],  #7
             [8.8,2100,32],
              [8.7,2000,25],
              [7.7,1500,20],   #10
              [9,3300,15],
              [8.1,1800,22],
              [8.4,2200,25],
              [8.9,2300,30],   #14
              [8.5,2000,22],
              [7.9,1900,18],
              [8,2300,16],
              [8.1,2200,16],
              [8.6,2500,18],
              [8.3,2400,15]])
y = np.array([262,190,220,140,185,171,150,200 ,220 ,250     ,130 , #11 
              200,185,195 #14
              ,210, 250,    
              230,  220   ,160,150]) # it does matter whether the data is sorted or not

# first, let us see if the gradient - partial derivative function - works and see its result applied on our data
w = np.random.rand(X.shape[1])
b = 0.5
lambda_m = 0.7
dj_db_m, dj_dw_m = compute_gradient(X, y, w, b, lambda_m)

print(f"dj_db: {dj_db_m}")
print(f"dj_dw: {dj_dw_m}")
# Out:
# dj_db: 493.49874584933303
# dj_dw: [   4143.12590173 1103666.50263729   10639.74928901]

# %%
def gradient_descent(X, y, w, b, compute_cost_linear_regression, compute_gradient, alpha, iterations):
    '''
    Descriptions: performs batch gradient descent to learn w vector and b parameter, using learning rate alpha and number of iterations
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    compute_cost_linear_regression, compute_gradient : functions to compute cost & gradient
                    alpha : learning rate
                    iterations: number of iterations
    Postconditons: w , b - updated values of parameters of the model & hist - array to store cost and w at every iteration
    '''
    hist = []
    for i in range(iterations):
        # calculate gradient for our parameters
        dj_db, dj_dw = compute_gradient(X, y, w, b)

        # update parameters using the learning rate
        w -= alpha* dj_dw
        b -= alpha* dj_db

        # save cost at every iteration if we do not have too many iterations (avoid resource exhaustion)
        if i<100000:
            hist.append(compute_cost_linear_regression(X, y, w, b))

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(iterations/ 10) == 0:
            print(f"Iteration {i:4d}: Cost {hist[-1]:8.2f}   ")

    return w, b, hist

# %%
# apply z-score normalization to bring our input data in the same range, so our model will perform faster and better

def zscore_normalize_features(X): 
    # description: computes  X, zcore normalized by column
    # pre: X - mxn array
    # post: X_norm : normalized data 

    # find the mean of each feature, by columns
    mu = np.mean(X, axis = 0) # nD array
    # find the standard deviation of each column
    sigma = np.std(X, axis=0) # nD array
    # apply the formula of the z-score normalization
    X_norm = (X - mu) / sigma      

    return X_norm

# %%
w_in= np.zeros((X.shape[1],))
b_in= 0

iterations=10000
alpha=0.05

X_norm = zscore_normalize_features(X)
print("Mean of each feature after normalization:", np.mean(X_norm, axis=0))
print("Std of each feature after normalization:", np.std(X_norm, axis=0))
w,b,cost_history=gradient_descent(X_norm, y, w_in, b_in, compute_cost_linear_regression, compute_gradient, alpha, iterations)

print("w,b found by gradient descent:", w, b)
print(f"Cost history: {cost_history}")
# Out:
# Mean of each feature after normalization: [-3.50587614e-16  2.22044605e-17  1.33226763e-16]
# Std of each feature after normalization: [1. 1. 1.]
# Iteration    0: Cost 17965.90
# Iteration 1000: Cost   478.64
# Iteration 2000: Cost   478.64
# Iteration 3000: Cost   478.64
# Iteration 4000: Cost   478.64
# Iteration 5000: Cost   478.64
# Iteration 6000: Cost   478.64
# Iteration 7000: Cost   478.64
# Iteration 8000: Cost   478.64
# Iteration 9000: Cost   478.64
# w,b found by gradient descent: [ -9.68106141 -12.5878967    2.37988332] 195.89999999999972
# Cost history: [17965.900114052056, 16250.56742165881, 14704.302628846204, 13310.299082795782, 12053.445922188273, 10920.152605470039, 9898.192344965359, 8976.562284594514, 8145.35852637328, 7395.664342167167, 6719.450107657855, 6109.4836696206285, 5559.250009184607, 5062.8791959448945, 4615.081743322228, 4211.090576718175, 3846.6089147455573, 3517.763441789986, 3221.0622188010366, 2953.3568397379, 2711.8083945484955, 2493.8568468401627, 2297.193476277209, 2119.736072883183, 1959.6066034108414, 1815.1110992710237, 1684.7215416176766, 1567.0595424487346, 1460.8816413315235, 1365.0660558854809, 1278.6007407070101, 1200.5726242229066, 1130.1579062049236, 1066.6133105403114, 1009.2681984827892, 957.5174571391767, 910.8150864969634, 868.6684159722183, 830.6328883483062, 796.30735516649, 765.329833192881, 737.3736765878601, 712.1441239020868, 689.3751830695792, 668.8268212093631, 650.2824293243594, 633.5465349365066, 618.442738353767, 604.8118506573663, 592.5102136529456, 581.4081839711397, 571.3887652528642, 562.3463739314637, 554.1857255451533, 546.8208297943511, 540.1740837134786, 534.1754533681367, 528.7617354275137, 523.8758908085813, 519.4664433521756, 515.486937179713, 511.8954470003782, 508.65413619884225, 505.7288580388941, 503.0887957742104, 500.70613786870007, 498.55578489983003, 496.6150850530135, 494.8635954170938, 493.2828665633671, 491.8562481363916, 490.5687134065845, 489.4067009347259, 488.3579716790225, 487.4114800383121, 486.5572574719883, 485.78630746987756, 485.0905107649963, 484.4625397901305, 483.8957814766521, 483.38426758193447, 482.92261181110933, 482.50595307052873, 482.12990425493103, 481.7905060286446, 481.4841851137953, 481.2077166459888, 480.9581902008127, 480.732979133178, 480.529712906444, 480.34625211977215, 480.18066597058555, 480.03121191468153, 479.8963173096846, 479.7745628484488, 479.6646676078542, 479.56547555548855, 479.4759433720406, 479.3951294611203, 479.3221840307073, 479.2563401417425, 479.1969056295499, 479.1432558129816, 479.09482691447346, 479.0511101216968, 479.01164622823563, 478.9760207968376, 478.94385979427886, 478.91482565185856, 478.88861371001764, 478.86494900963146, 478.84358339616904, 478.82429290621366, 478.8068754088115, 478.7911484768034, 478.7769474657101, 478.7641237799386, 478.7525433080385, 478.7420850105309, 478.7326396454294, 478.7241086180266, 478.7164029428327, 478.709442306728, 478.70315422346147, 478.69747327058843, 478.6923404008081, 478.68770232044903, 478.68351092855283, 478.67972281064715, 478.6762987818776, 478.6732034746861, 478.67040496668756, 478.6678744448317, 478.66558590230727, 478.6635158649986, 478.6616431446105, 478.6599486158673, 478.65841501542826, 478.6570267604138, 478.6557697846196, 478.654631390704, 478.6536001167812, 478.65266561602505, 478.6518185480079, 478.65105048063333, 478.6503538016299, 478.6497216386735, 478.6491477872959, 478.6486266458211, 478.6481531566458, 478.6477227532414, 478.64733131232555, 478.64697511069295, 478.64665078625586, 478.6463553028806, 478.6460859186539, 478.6458401572395, 478.64561578202836, 478.6454107728075, 478.6452233047032, 478.6450517291751, 478.6448945568635, 478.6447504421081, 478.6446181689746, 478.644496638643, 478.64438485802657, 478.6442819294945, 478.6441870416022, 478.64409946072016, 478.64401852348004, 478.6439436299554, 478.6438742375072, 478.64380985522865, 478.64375003893116, 478.64369438661737, 478.64364253439567, 478.64359415279284, 478.6435489434246, 478.6435066359897, 478.64346698555846, 478.64342977012313, 478.64339478838656, 478.64336185776796, 478.6433308125991, 478.6433015024992, 478.64327379090605, 478.6432475537487, 478.64322267825156, 478.643199061853, 478.6431766112292, 478.64315524141193, 478.64313487499396, 478.643115441409, 478.6430968762831, 478.64307912084786, 478.6430621214112, 478.6430458288784, 478.6430301983205, 478.64301518858326, 478.6430007619349, 478.6429868837471, 478.64297352220694, 478.6429606480559, 478.6429482343563, 478.64293625627613, 478.6429246908994, 478.642913 ...

# %%
# form the output given by our predictions of w and b

# plot the cost resulted, which is in our cost hist array

fig, (ax1, ax2) = plt.subplots(1,2, constrained_layout=True, figsize=(15,5)) # create 2 pictures in the same row to show how fast does the cost decrease
ax1.plot(cost_history)
ax1.set_title("Cost vs iterations")
ax1.set_xlabel("Iteration step")
ax1.set_ylabel("Cost")

ax2.plot(np.arange(len(cost_history[200:])), cost_history[200:])
ax2.set_title("Cost vs iterations")
ax2.set_xlabel("Iteration step")
ax2.set_ylabel("Cost")

plt.show()

# %%
# prepare the predicted output for plotting
m = X.shape[0]
yp = np.zeros(m)
for i in range(m):
  yp[i] = np.dot(X[i], w) + b

X_features=["feature 1", "feature 2", "feature 3"]
# plot predict
fig, ax = plt.subplots(1,X.shape[1], figsize=(12,3), sharey=True)
for i in range(len(ax)):
  ax[i].scatter( X[:,i], y, color="blue", label= 'target')
  ax[i].scatter( X[:,i], yp, color='red', label='predict')
  ax[i].set_xlabel(X_features[i])
ax[0].set_ylabel("Price")
ax[0].legend()
plt.show()
