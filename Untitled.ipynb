# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def compute_cost_linear_regression(X, y, w, b, lambda_l=1):
    '''
    Description: computes the cost for regularized linear regression
    ( the term with the numerator lambda helps to minimize the size of the parameters 
    (w1, w2,...),
    but I use the version where b is not regularized )
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: total_cost - real number - the cost of our calculations, which will help
    later to build a better model
    '''
    m = X.shape[0] # number of input data examples
    n = X.shape[1] # number of features of each example

    cost = 0
    for i in range(m):
       f_wb = np.dot(X[i],w)+b # the formula of linear regression model
       cost+= (f_wb-y[i])**2 
    cost = cost/(2*m)    # until here, we just applied the formula of the cost without regularization

    # the regularization part
    cost_r = 0
    for j in range(n):
        cost_r+= w[j]**2
    cost_r = (lambda_l/(2*m))* cost_r

    # adding the 2 costs
    total_cost = cost + cost_r
    return total_cost

# %%
# EXAMPLES PART - DOES NOT AFFECT OUR FINAL MODEL

np.random.seed(1) #running the cost function for some random input data (10 examples with 5 features each)
X1 = np.random.rand(10,5) 
y1 = np.array([0,1,0,0,1,1,1,1,0,1])
w1 = np.random.rand(5) - 0.5 
print(w1)
b1 = 0.5
lambda1 = 0.7
cost1 = compute_cost_linear_regression(X1, y1, w1, b1, lambda1)

print("Regularized cost example1:", cost1)


np.random.seed(1)  
X2 = np.random.rand(4,3) 
y2 = np.array([0,1,0,0])
w2 = np.random.rand(3) - 0.5
print(w2)
b2 = 0.5
lambda2 = 0.7
cost2 = compute_cost_linear_regression(X2, y2, w2, b2, lambda2)

print("Regularized cost example2:", cost2)
# Out:
# [-0.48063304  0.17883553 -0.28837188 -0.23445334 -0.00842684]
# Regularized cost example1: 0.236003117924045
# [-0.29554775  0.37811744 -0.47261241]
# Regularized cost example2: 0.1567201382524095

# %%
for i in range (X1.shape[1]):
    plt.scatter(X1[i,0], y1[i], marker='x', color='red') # use a scatter plot to display the data considering only the first feature of each example
#add a title & set x and y label
plt.title("Input vs Target")
plt.xlabel("input data")
plt.ylabel("target values")
plt.show()
# EXAMPLES PART - DOES NOT AFFECT OUR FINAL MODEL

# %%
def compute_gradient(X, y, w, b, lambda_l=0.3):
    '''
    Description: computes the partial derivative of the w vector and b scalar used in the gradient descent algorithm 
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: dj_dw - n array (size of w) and dj_db - scalar
    '''
    m = X.shape[0]
    n = X.shape[1]

    dj_dw = np.zeros((n,)) # null vector of n size
    dj_db = 0
    
    for i in range(m):
        f_wb = np.dot(X[i],w)+b
        aux = (f_wb - y[i])
        dj_db += aux # forming the derivative of b 

        # forming the gradient of w - unregularized part for now
        for j in range(n):
            dj_dw[j] += aux* X[i,j]

    dj_dw /= m
    dj_db /= m

    #now add the regularization part for the w feature vector
    for j in range(n):
        dj_dw[j] += (lambda_l/m) * w[j]

    return dj_db, dj_dw

# %%
# this is where HOTEL RENT PREDICTION MODEL data is taken as input

'''
We have 20 room rent examples with price per person/ night in Cluj-Napoca                         - OUTPUT
Each room has 4 features:                                          
 - number of stars on reviews : 0-10                                                               - INPUT
 - distance from the city center (meters)
 - room area (meters^2)
 '''

X = np.array([[6.8,1900,17],
              [8.4,1900,16],
              [8.4,1900,20],
              [8.7,2300,30],
              [8.7,2300,36],
              [8.6,2300,20],
              [7.1,1400,16],  #7
             [8.8,2100,32],
              [8.7,2000,25],
              [7.7,1500,20],   #10
              [9,3300,15],
              [8.1,1800,22],
              [8.4,2200,25],
              [8.9,2300,30],   #14
              [8.5,2000,22],
              [7.9,1900,18],
              [8,2300,16],
              [8.1,2200,16],
              [8.6,2500,18],
              [8.3,2400,15]])
y = np.array([262,190,220,140,185,171,150,200 ,220 ,250     ,130 , #11 
              200,185,195 #14
              ,210, 250,    
              230,  220   ,160,150]) # it does matter whether the data is sorted or not

# first, let us see if the gradient - partial derivative function - works and see its result applied on our data
w = np.random.rand(X.shape[1])
b = 0.5
lambda_m = 0.7
dj_db_m, dj_dw_m = compute_gradient(X, y, w, b, lambda_m)

print(f"dj_db: {dj_db_m}")
print(f"dj_dw: {dj_dw_m}")
# Out:
# dj_db: 708.9114251721343
# dj_dw: [   5941.95738012 1577044.91555992   15258.91494592]

# %%
def gradient_descent(X, y, w, b, compute_cost_linear_regression, compute_gradient, alpha, iterations):
    '''
    Descriptions: performs batch gradient descent to learn w vector and b parameter, using learning rate alpha and number of iterations
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    compute_cost_linear_regression, compute_gradient : functions to compute cost & gradient
                    alpha : learning rate
                    iterations: number of iterations
    Postconditons: w , b - updated values of parameters of the model & hist - array to store cost and w at every iteration
    '''
    hist = []
    for i in range(iterations):
        # calculate gradient for our parameters
        dj_db, dj_dw = compute_gradient(X, y, w, b)

        # update parameters using the learning rate
        w -= alpha* dj_dw
        b -= alpha* dj_db

        # save cost at every iteration if we do not have too many iterations (avoid resource exhaustion)
        if i<100000:
            hist.append(compute_cost_linear_regression(X, y, w, b))

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(iterations/ 10) == 0:
            print(f"Iteration {i:4d}: Cost {hist[-1]:8.2f}   ")

    return w, b, hist

# %%
# apply z-score normalization to bring our input data in the same range, so our model will perform faster and better

def zscore_normalize_features(X): 
    # description: computes  X, zcore normalized by column
    # pre: X - mxn array
    # post: X_norm : normalized data 

    # find the mean of each feature, by columns
    mu = np.mean(X, axis = 0) # nD array
    # find the standard deviation of each column
    sigma = np.std(X, axis=0) # nD array
    # apply the formula of the z-score normalization
    X_norm = (X - mu) / sigma      

    return X_norm

# %%
w_in= np.zeros((X.shape[1],))
b_in= 0

iterations=500
alpha=0.01

X_norm = zscore_normalize_features(X)
w,b,cost_history=gradient_descent(X_norm, y, w_in, b_in, compute_cost_linear_regression, compute_gradient, alpha, iterations)

print("w,b found by gradient descent:", w, b)
print(f"Cost history: {cost_history}")
# Out:
# Iteration    0: Cost 19480.47
# Iteration   50: Cost  7400.83
# Iteration  100: Cost  3006.82
# Iteration  150: Cost  1403.00
# Iteration  200: Cost   816.76
# Iteration  250: Cost   602.35
# Iteration  300: Cost   523.93
# Iteration  350: Cost   495.26
# Iteration  400: Cost   484.78
# Iteration  450: Cost   480.95
# w,b found by gradient descent: [ -9.73025595 -12.98810838   2.41448005] 194.61284237199095
# Cost history: [19480.46981423268, 19099.766811359197, 18726.73178753919, 18361.20883157675, 18003.045254892255, 17652.091523050905, 17308.201188810883, 16971.230826655323, 16641.039968773086, 16317.491042454134, 16000.449308866398, 15689.782803181603, 15385.36227601856, 15087.061136173139, 14794.755394604883, 14508.323609651075, 14227.646833439716, 13952.608559473618, 13683.094671358534, 13418.993392648943, 13160.195237785569, 12906.592964099773, 12658.081524860047, 12414.55802333693, 12175.92166786287, 11942.073727864483, 11712.917490844839, 11488.358220294314, 11268.303114508848, 11052.661266294943, 10841.34362354149, 10634.262950638647, 10431.333790724806, 10232.472428742853, 10037.596855287626, 9846.626731226726, 9659.483353077361, 9476.089619122327, 9296.36999624855, 9120.2504874921, 8947.65860027392, 8778.523315310907, 8612.775056187329, 8450.34565957194, 8291.16834606649, 8135.177691671653, 7982.309599856754, 7832.501274219961, 7685.691191725932, 7541.819076508253, 7400.825874224221, 7262.653726949875, 7127.245948603449, 6994.547000885666, 6864.5024697256185, 6737.059042221149, 6612.164484063032, 6489.76761743234, 6369.818299360812, 6252.26740054406, 6137.0667845979115, 6024.169287748195, 5913.528698944654, 5805.099740389816, 5698.838048473847, 5594.700155106649, 5492.643469438664, 5392.626259962024, 5294.607636983833, 5198.547535463681, 5104.406698207495, 5012.146659410177, 4921.729728539506, 4833.11897455406, 4746.278210447991, 4661.171978115747, 4577.765533529835, 4496.02483222505, 4415.916515082614, 4337.407894407857, 4260.466940295241, 4185.062267274589, 4111.16312123262, 4038.739366603921, 3967.7614738256916, 3898.2005070506725, 3830.0281121128187, 3763.216504740397, 3697.7384590112797, 3633.5672960453544, 3570.676872929054, 3509.041571867138, 3448.6362895569537, 3389.436426780497, 3331.4178782097415, 3274.557022420728, 3218.8307121120874, 3164.2162645236813, 3110.6914520512255, 3058.234493052759, 3006.824042842992, 2956.439184871594, 2907.0594220816083, 2858.6646684442167, 2811.2352406662235, 2764.7518500666283, 2719.1955946188086, 2674.5479511548515, 2630.790767728678, 2587.9062561346686, 2545.8769845785773, 2504.6858704975516, 2464.316173526209, 2424.751488605722, 2385.9757392329693, 2347.9731708468603, 2310.7283443489814, 2274.2261297558307, 2238.4516999798825, 2203.390524736864, 2169.028364576625, 2135.3512650350494, 2102.3455509045452, 2069.997820620645, 2038.294940762344, 2007.2240406638487, 1976.772507135412, 1946.9279792910743, 1917.6783434810538, 1889.0117283266895, 1860.916499855802, 1833.381256736444, 1806.3948256069934, 1779.946256500652, 1754.024818362384, 1728.619994656433, 1703.7214790625492, 1679.3191712591172, 1655.4031727914137, 1631.9637830232537, 1608.9914951703279, 1586.4769924135571, 1564.4111440908366, 1542.7850019655768, 1521.5897965704726, 1500.8169336249555, 1480.4579905248618, 1460.5047129028053, 1440.9490112578553, 1421.782957653075, 1402.9987824795724, 1384.5888712856895, 1366.545761670018, 1348.8621402369358, 1331.5308396134092, 1314.5448355258002, 1297.8972439354764, 1281.5813182320223, 1265.5904464828843, 1249.9181487383064, 1234.5580743904436, 1219.503999585538, 1204.7498246881028, 1190.2895717960478, 1176.1173823057186, 1162.2275145258398, 1148.6143413393766, 1135.2723479123395, 1122.1961294485818, 1109.380388989672, 1096.8199352589154, 1084.5096805486426, 1072.4446386498842, 1060.619922823584, 1049.0307438125012, 1037.6724078929944, 1026.5403149658655, 1015.6299566854896, 1004.9369146264523, 994.4568584869387, 984.185544328133, 974.1188128489027, 964.2525876950594, 954.5828738024924, 945.1057557734991, 935.817396285644, 926.714034532482, 917.7919846955187, 909.0476344467667, 900.477443481286, 892.0779420791094, 883.8457296959542, 875.7774735821492, 867.8699074291999, 860.1198300434463, 852.5241040462622, 845.0796546002632, 837.7834681610009, 830.6325912536356, 823.6241292740781, 816.7552453141133, 810.0231590100236, 803.4251454142417, 796.9585338895666, 790.6207070254894, 784.40 ...

# %%
# form the output given by our predictions of w and b

# plot the cost resulted, which is in our cost hist array

fig, (ax1, ax2) = plt.subplots(1,2, constrained_layout=True, figsize=(15,5)) # create 2 pictures in the same row to show how fast does the cost decrease
ax1.plot(cost_history)
ax1.set_title("Cost vs iterations")
ax1.set_xlabel("Iteration step")
ax1.set_ylabel("Cost")

ax2.plot(np.arange(len(cost_history[200:])), cost_history[200:])
ax2.set_title("Cost vs iterations")
ax2.set_xlabel("Iteration step")
ax2.set_ylabel("Cost")

plt.show()

# %%
# prepare the predicted output for plotting
m = X.shape[0]
yp = np.zeros(m)
for i in range(m):
  yp[i] = np.dot(X[i], w) + b

X_features=["feature 1", "feature 2", "feature 3"]
# plot predict
fig, ax = plt.subplots(1,X.shape[1], figsize=(12,3), sharey=True)
for i in range(len(ax)):
  ax[i].scatter( X[:,i], y, color="blue", label= 'target')
  ax[i].scatter( X[:,i], yp, color='red', label='predict')
  ax[i].set_xlabel(X_features[i])
ax[0].set_ylabel("Price")
ax[0].legend()
plt.show()
