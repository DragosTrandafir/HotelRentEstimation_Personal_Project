# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def compute_cost_linear_regression(X, y, w, b, lambda_l=1):
    '''
    Description: computes the cost for regularized linear regression
    ( the term with the numerator lambda helps to minimize the size of the parameters 
    (w1, w2,...),
    but I use the version where b is not regularized )
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: total_cost - real number - the cost of our calculations, which will help
    later to build a better model
    '''
    m = X.shape[0] # number of input data examples
    n = X.shape[1] # number of features of each example

    cost = 0
    for i in range(m):
       f_wb = np.dot(X[i],w)+b # the formula of linear regression model
       cost+= (f_wb-y[i])**2 
    cost = cost/(2*m)    # until here, we just applied the formula of the cost without regularization

    # the regularization part
    cost_r = 0
    for j in range(n):
        cost_r+= w[j]**2
    cost_r = (lambda_l/(2*m))* cost_r

    # adding the 2 costs
    total_cost = cost + cost_r
    return total_cost

# %%
np.random.seed(1) #running the cost function for some random input data (10 examples with 5 features each)
X1 = np.random.rand(10,5) 
y1 = np.array([0,1,0,0,1,1,1,1,0,1])
w1 = np.random.rand(5) - 0.5 
print(w1)
b1 = 0.5
lambda1 = 0.7
cost1 = compute_cost_linear_regression(X1, y1, w1, b1, lambda1)

print("Regularized cost example1:", cost1)


np.random.seed(1)  
X2 = np.random.rand(4,3) 
y2 = np.array([0,1,0,0])
w2 = np.random.rand(3) - 0.5
print(w2)
b2 = 0.5
lambda2 = 0.7
cost2 = compute_cost_linear_regression(X2, y2, w2, b2, lambda2)

print("Regularized cost example2:", cost2)
# Out:
# [-0.48063304  0.17883553 -0.28837188 -0.23445334 -0.00842684]
# Regularized cost example1: 0.236003117924045
# [-0.29554775  0.37811744 -0.47261241]
# Regularized cost example2: 0.1567201382524095

# %%
def compute_gradient(X, y, w, b, lambda_l=1):
    '''
    Description: computes the partial derivative of the w vector and b scalar used in the gradient descent algorithm 
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: dj_dw - n array (size of w) and dj_db - scalar
    '''
    m = X.shape[0]
    n = X.shape[1]

    dj_dw = np.zeros((n,)) # null vector of n size
    dj_db = 0
    
    for i in range(m):
        f_wb = np.dot(X[i],w)+b
        aux = (f_wb - y[i])
        dj_db += aux # forming the derivative of b 

        # forming the gradient of w - unregularized part for now
        for j in range(n):
            dj_dw[j] += aux* X[i,j]

    dj_dw /= m
    dj_db /= m

    #now add the regularization part for the w feature vector
    for j in range(n):
        dj_dw[j] += (lambda_l/m) * w[j]

    return dj_db, dj_dw

# %%
# testing the gradient function to see the results
np.random.seed(1)
X1 = np.random.rand(20,4)
y1 = np.array([0.7,1,0,1,0.45,1,0,1,0,1,1,0.2,1,0,0,1,0,1,0.3,0])
w1 = np.random.rand(X1.shape[1])
b1 = 0.5
lambda1 = 0.7
dj_db1, dj_dw1 = compute_gradient(X1, y1, w1, b1, lambda1)

print(f"dj_db: {dj_db1}")
print(f"dj_dw: {dj_dw1}")
# Out:
# dj_db: 1.1794843967613495
# dj_dw: [0.71501008 0.70255245 0.59429547 0.53291232]

# %%
for i in range (20):
    plt.scatter(X1[i,0], y1[i], marker='x', color='red') # use a scatter plot to display the data considering only the first feature of each example
#add a title & set x and y label
plt.title("Input vs Target")
plt.xlabel("input data")
plt.ylabel("target values")
plt.show()

# %%
def gradient_descent(X, y, w, b, compute_cost_linear_regression, compute_gradient, alpha, iterations):
    '''
    Descriptions: performs batch gradient descent to learn w vector and b parameter, using learning rate alpha and number of iterations
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    compute_cost_linear_regression, compute_gradient : functions to compute cost & gradient
                    alpha : learning rate
                    iterations: number of iterations
    Postconditons: w , b - updated values of parameters of the model & hist - array to store cost and w at every iteration
    '''
    hist = []
    for i in range(iterations):
        # calculate gradient for our parameters
        dj_db, dj_dw = compute_gradient(X, y, w, b)

        # update parameters using the learning rate
        w -= alpha* dj_dw
        b -= alpha* dj_db

        # save cost at every iteration if we do not have too many iterations (avoid resource exhaustion)
        if i<100000:
            hist.append(compute_cost_linear_regression(X, y, w, b))

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(iterations/ 10) == 0:
            print(f"Iteration {i:4d}: Cost {hist[-1]:8.2f}   ")

    return w, b, hist

# %%
# apply z-score normalization to bring our input data in the same range, so our model will perform faster and better

def zscore_normalize_features(X): 
    # description: computes  X, zcore normalized by column
    # pre: X - mxn array
    # post: X_norm : normalized data 

    # find the mean of each feature, by columns
    mu = np.mean(X, axis = 0) # nD array
    # find the standard deviation of each column
    sigma = np.std(X, axis=0) # nD array
    # apply the formula of the z-score normalization
    X_norm = (X - mu) / sigma      

    return X_norm

# %%
w_in= np.zeros((X1.shape[1],))
b_in= 0

iterations=500
alpha=0.01

X_norm = zscore_normalize_features(X1)
w,b,cost_history=gradient_descent(X_norm, y1, w1, b1, compute_cost_linear_regression, compute_gradient, alpha, iterations)

print("w,b found by gradient descent:", w, b)
print(f"Cost history: {cost_history}")
# Out:
# Iteration    0: Cost     1.16
# Iteration   50: Cost     0.43
# Iteration  100: Cost     0.20
# Iteration  150: Cost     0.12
# Iteration  200: Cost     0.10
# Iteration  250: Cost     0.09
# Iteration  300: Cost     0.08
# Iteration  350: Cost     0.08
# Iteration  400: Cost     0.08
# Iteration  450: Cost     0.08
# w,b found by gradient descent: [-0.04948266  0.08649144 -0.12550309  0.10659416] 0.5322864593011218
# Cost history: [1.1557026596853759, 1.13158133069117, 1.108013506224471, 1.0849862904474665, 1.062487091591168, 1.0405036147056606, 1.0190238545851953, 0.9980360888638578, 0.9775288712776379, 0.9574910250888564, 0.9379116366689754, 0.9187800492359399, 0.9000858567422763, 0.8818188979102819, 0.8639692504107169, 0.8465272251815064, 0.829483360883047, 0.8128284184867868, 0.7965533759938456, 0.7806494232805065, 0.7651079570674953, 0.7499205760100446, 0.7350790759057999, 0.7205754450177124, 0.7064018595091238, 0.6925506789883218, 0.679014442159905, 0.6657858625803761, 0.6528578245154245, 0.640223378896444, 0.6278757393738719, 0.6158082784650118, 0.6040145237940441, 0.5924881544220006, 0.5812229972645179, 0.5702130235952527, 0.5594523456328806, 0.5489352132096652, 0.5386560105196153, 0.5286092529443185, 0.5187895839545664, 0.5091917720859424, 0.4998107079865915, 0.4906414015354234, 0.4816789790290524, 0.47291868043581725, 0.4643558567152622, 0.45598596720150003, 0.4478045770489192, 0.43980735473873406, 0.43199006964490877, 0.4243485896580316, 0.41687887886573716, 0.40957699528832303, 0.40243908866822825, 0.39546139831208, 0.38864025098404503, 0.3819720588492528, 0.3754533174660848, 0.3690806038261603, 0.3628505744408697, 0.35675996347333977, 0.3508055809147403, 0.34498431080386727, 0.3392931094889654, 0.33372900393077776, 0.3282890900458322, 0.3229705310890021, 0.31777055607440036, 0.3126864582336867, 0.30771559351089495, 0.3028553790929041, 0.29810329197470065, 0.2934568675586006, 0.2889136982866181, 0.2844714323051879, 0.280127772161469, 0.27588047353047435, 0.27172734397228937, 0.2676662417186629, 0.26369507448826557, 0.25981179832993523, 0.25601441649323775, 0.25230097832569526, 0.24866957819604196, 0.24511835444288954, 0.24164548834819516, 0.23824920313494202, 0.23492776298845322, 0.2316794721007793, 0.22850267373760663, 0.22539574932715348, 0.22235711757052767, 0.2193852335730369, 0.21647858799595326, 0.21363570622824432, 0.21085514757779703, 0.2081355044816707, 0.20547540173492715, 0.20287349573759592, 0.20032847375934457, 0.19783905322143402, 0.1954039809955465, 0.19302203271908835, 0.19069201212657483, 0.1884127503967163, 0.1861831055148334, 0.1840019616502373, 0.18186822854822007, 0.17978084093631097, 0.17773875794445734, 0.1757409625388036, 0.17378646096874337, 0.17187428222693327, 0.17000347752195968, 0.1681731197633593, 0.16638230305870258, 0.1646301422224525, 0.16291577229632306, 0.16123834808086274, 0.15959704367799962, 0.1579910520442889, 0.15641958455460894, 0.15488187057606032, 0.1533771570518263, 0.15190470809475987, 0.1504638045904675, 0.1490537438096661, 0.1476738390295937, 0.1463234191642611, 0.14500182840333561, 0.14370842585945345, 0.14244258522376219, 0.14120369442949957, 0.13999115532341908, 0.1388043833448778, 0.1376428072124058, 0.1365058686175815, 0.13539302192604002, 0.13430373388544864, 0.13323748334028293, 0.13219376095324592, 0.1311720689331729, 0.13017192076926953, 0.129192840971535, 0.12823436481722397, 0.12729603810320653, 0.126377416904087, 0.12547806733594602, 0.12459756532557549, 0.1237354963850752, 0.12289145539168739, 0.12206504637274528, 0.12125588229561586, 0.12046358486251964, 0.1196877843101141, 0.11892811921372728, 0.11818423629613463, 0.11745579024077107, 0.11674244350927541, 0.11604386616326526, 0.11535973569024313, 0.11468973683353807, 0.11403356142618697, 0.11339090822866442, 0.1127614827703711, 0.11214499719479186, 0.11154117010823898, 0.11094972643209572, 0.11037039725847925, 0.10980291970924216, 0.10924703679823561, 0.10870249729675689, 0.10816905560210797, 0.1076464716091917, 0.10713451058507534, 0.10663294304645164, 0.10614154463993042, 0.10566009602509416, 0.10518838276025358, 0.10472619519083977, 0.10427332834037206, 0.10382958180394085, 0.10339475964414765, 0.10296867028944422, 0.1025511264348156, 0.10214194494475237, 0.10174094675845831, 0.10134795679724239, 0.10096280387404319, 0.100585320605037, 0.10021534332328076, 0.09985271199434258, 0.09949727013387347, 0.09914886472707 ...

# %%
# form the output given by our predictions of w and b

# plot the cost resulted, which is in our cost hist array

fig, (ax1, ax2) = plt.subplots(1,2, constrained_layout=True, figsize=(15,5)) # create 2 pictures in the same row to show how fast does the cost decrease
ax1.plot(cost_history)
ax1.set_title("Cost vs iterations")
ax1.set_xlabel("Iteration step")
ax1.set_ylabel("Cost")

ax2.plot(np.arange(len(cost_history[200:])), cost_history[200:])
ax2.set_title("Cost vs iterations")
ax2.set_xlabel("Iteration step")
ax2.set_ylabel("Cost")

plt.show()

# %%
# prepare the predicted output for plotting
m = X1.shape[0]
yp = np.zeros(m)
for i in range(m):
  yp[i] = np.dot(X1[i], w) + b

X_features=["feature 1", "feature 2", "feature 3", "feature 4"]
# plot predict
fig, ax = plt.subplots(1,X1.shape[1], figsize=(12,3), sharey=True)
for i in range(len(ax)):
  ax[i].scatter( X1[:,i], y1, color="blue", label= 'target')
  ax[i].scatter( X1[:,i], yp, color='red', label='predict')
  ax[i].set_xlabel(X_features[i])
ax[0].set_ylabel("Price")
ax[0].legend()
plt.show()
