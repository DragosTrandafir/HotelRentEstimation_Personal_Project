# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def compute_cost_linear_regression(X, y, w, b, lambda_l=1):
    '''
    Description: computes the cost for regularized linear regression
    ( the term with the numerator lambda helps to minimize the size of the parameters 
    (w1, w2,...),
    but I use the version where b is not regularized )
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: total_cost - real number - the cost of our calculations, which will help
    later to build a better model
    '''
    m = X.shape[0] # number of input data examples
    n = len(w) # number of features of each example

    cost = 0.
    for i in range(m):
       f_wb = np.dot(X[i],w)+b # the formula of linear regression model
       cost+= (f_wb-y[i])**2 
    cost = cost/(2*m)    # until here, we just applied the formula of the cost without regularization

    # the regularization part
    cost_r = 0
    for j in range(n):
        cost_r+= w[j]**2
    cost_r = (lambda_l/(2*m))* cost_r

    # adding the 2 costs
    total_cost = cost + cost_r
    return total_cost

# %%
# EXAMPLES PART - DOES NOT AFFECT OUR FINAL MODEL

np.random.seed(1) #running the cost function for some random input data (10 examples with 5 features each)
X1 = np.random.rand(10,5) 
y1 = np.array([0,1,0,0,1,1,1,1,0,1])
w1 = np.random.rand(5) - 0.5 
print(w1)
b1 = 0.5
lambda1 = 0.7
cost1 = compute_cost_linear_regression(X1, y1, w1, b1, lambda1)

print("Regularized cost example1:", cost1)


np.random.seed(1)  
X2 = np.random.rand(4,3) 
y2 = np.array([0,1,0,0])
w2 = np.random.rand(3) - 0.5
print(w2)
b2 = 0.5
lambda2 = 0.7
cost2 = compute_cost_linear_regression(X2, y2, w2, b2, lambda2)

print("Regularized cost example2:", cost2)
# Out:
# [-0.48063304  0.17883553 -0.28837188 -0.23445334 -0.00842684]
# Regularized cost example1: 0.236003117924045
# [-0.29554775  0.37811744 -0.47261241]
# Regularized cost example2: 0.1567201382524095

# %%
for i in range (X1.shape[1]):
    plt.scatter(X1[i,0], y1[i], marker='x', color='red') # use a scatter plot to display the data considering only the first feature of each example
#add a title & set x and y label
plt.title("Input vs Target")
plt.xlabel("input data")
plt.ylabel("target values")
plt.show()
# EXAMPLES PART - DOES NOT AFFECT OUR FINAL MODEL

# %%
def compute_gradient(X, y, w, b, lambda_l):
    '''
    Description: computes the partial derivative of the w vector and b scalar used in the gradient descent algorithm 
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: dj_dw - n array (size of w) and dj_db - scalar
    '''
    m = X.shape[0]
    n = X.shape[1]

    dj_dw = np.zeros((n,)) # null vector of n size
    dj_db = 0.0
    
    for i in range(m):
        f_wb = np.dot(X[i],w)+b
        aux = (f_wb - y[i])
        dj_db += aux # forming the derivative of b 

        # forming the gradient of w - unregularized part for now
        for j in range(n):
            dj_dw[j] += aux* X[i,j]

    dj_dw /= m
    dj_db /= m

    #now add the regularization part for the w feature vector
    for j in range(n):
        dj_dw[j] += (lambda_l/m) * w[j]

    return dj_db, dj_dw

# %%
# this is where HOTEL RENT PREDICTION MODEL data is taken as input

'''
We have 20 room rent examples with price per person/ night in Cluj-Napoca                         - OUTPUT
Each room has 4 features:                                          
 - number of stars on reviews : 0-10                                                               - INPUT
 - distance from the city center (meters)
 - room area (meters^2)
 '''

X = np.array([[6.8,1900,17],
              [8.4,1900,16],
              [8.4,1900,20],
              [8.7,2300,30],
              [8.7,2300,36],
              [8.6,2300,20],
              [7.1,1400,16],  #7
             [8.8,2100,32],
              [8.7,2000,25],
              [7.7,1500,20],   #10
              [9,3300,15],
              [8.1,1800,22],
              [8.4,2200,25],
              [8.9,2300,30],   #14
              [8.5,2000,22],
              [7.9,1900,18],
              [8,2300,16],
              [8.1,2200,16],
              [8.6,2500,18],
              [8.3,2400,15]])
X_norm = zscore_normalize_features(X)
y = np.array([262,190,220,140,185,171,150,200 ,220 ,250     ,130 , #11 
              200,185,195 #14
              ,210, 250,    
              230,  220   ,160,150]) # it does matter whether the data is sorted or not

# first, let us see if the gradient - partial derivative function - works and see its result applied on our data
w = np.random.rand(X_norm.shape[1])
b = 0.5
lambda_m = 0.7
dj_db_m, dj_dw_m = compute_gradient(X_norm, y, w, b,  lambda_m)

print(f"dj_db: {dj_db_m}")
print(f"dj_dw: {dj_dw_m}")
# Out:
# dj_db: -195.39999999999998
# dj_dw: [18.32559268 20.26373122  3.29924752]

# %%
def gradient_descent(X, y, w, b, compute_cost_linear_regression, compute_gradient, alpha, iterations):
    '''
    Descriptions: performs batch gradient descent to learn w vector and b parameter, using learning rate alpha and number of iterations
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    compute_cost_linear_regression, compute_gradient : functions to compute cost & gradient
                    alpha : learning rate
                    iterations: number of iterations
    Postconditons: w , b - updated values of parameters of the model & hist - array to store cost and w at every iteration
    '''
    hist = []
    for i in range(iterations):
        # calculate gradient for our parameters
        dj_db, dj_dw = compute_gradient(X, y, w, b,0.7)

        # update parameters using the learning rate
        w -= alpha* dj_dw
        b -= alpha* dj_db

        # save cost at every iteration if we do not have too many iterations (avoid resource exhaustion)
        if i<100000:
            hist.append(compute_cost_linear_regression(X, y, w, b))

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(iterations/ 10) == 0:
            print(f"Iteration {i:4d}: Cost {hist[-1]:8.2f}   ")

    return w, b, hist

# %%
# apply z-score normalization to bring our input data in the same range, so our model will perform faster and better

def zscore_normalize_features(X): 
    # description: computes  X, zcore normalized by column
    # pre: X - mxn array
    # post: X_norm : normalized data 

    # find the mean of each feature, by columns
    mu = np.mean(X, axis = 0) # nD array
    # find the standard deviation of each column
    sigma = np.std(X, axis=0) # nD array
    # apply the formula of the z-score normalization
    X_norm = (X - mu) / sigma      

    return X_norm

# %%
w_in= np.zeros((X_norm.shape[1],))
b_in= 0

iterations=1000
alpha=0.01 # 5.0e-7


w,b,cost_history=gradient_descent(X_norm, y, w_in, b_in, compute_cost_linear_regression, compute_gradient, alpha, iterations)

print("w,b found by gradient descent:", w, b)
print(f"Cost history: {cost_history}")
# Out:
# Iteration    0: Cost 19480.47
# Iteration  100: Cost  3007.27
# Iteration  200: Cost   816.91
# Iteration  300: Cost   523.94
# Iteration  400: Cost   484.72
# Iteration  500: Cost   479.47
# Iteration  600: Cost   478.77
# Iteration  700: Cost   478.68
# Iteration  800: Cost   478.67
# Iteration  900: Cost   478.66
# w,b found by gradient descent: [ -9.73669374 -12.74630088   2.4353062 ] 195.89154275263223
# Cost history: [19480.46981423268, 19099.768112732156, 18726.735579818363, 18361.21619913704, 18003.057183288234, 17652.108905027544, 17308.2248300027, 16971.26145098872, 16641.07822358604, 16317.537503346774, 16000.504484295392, 15689.84713881067, 15385.436158836887, 15087.144898392899, 14794.84931734865, 14508.427926439263, 14227.761733487872, 13952.734190808897, 13683.231143764147, 13419.140780445137, 13160.353582455236, 12906.762276766302, 12658.261788624866, 12414.749195483699, 12176.123681935032, 11942.286495622531, 11713.140904109405, 11488.592152680814, 11268.54742305924, 11052.915793011898, 10841.608196829871, 10634.537386659207, 10431.617894664536, 10232.765996006385, 10037.899672613783, 9846.938577734152, 9659.80400124301, 9476.41883569628, 9296.707543108643, 9120.596122441539, 8948.01207778496, 8778.884387217518, 8613.143472329635, 8450.721168395037, 8291.550695176207, 8135.566628349612, 7982.704871536995, 7832.902628929315, 7686.098378490171, 7542.231845725977, 7401.243978010327, 7263.076919450377, 7127.6739862832965, 6994.979642791182, 6864.93947772301, 6737.50018121259, 6612.609522181581, 6490.2163262170825, 6370.270453913339, 6252.722779667535, 6137.525170919747, 6024.630467827418, 5913.992463364941, 5805.565883839105, 5699.306369811424, 5595.170457418564, 5493.115560082219, 5393.099950600123, 5295.082743609873, 5199.023878417679, 5104.884102184053, 5012.624953458895, 4922.208746058418, 4833.598553276598, 4746.758192424017, 4661.652209687065, 4578.245865300704, 4496.505119028062, 4416.396615940354, 4337.887672490728, 4260.946262875771, 4185.541005678591, 4111.64115078749, 4039.216566584363, 3968.237727397166, 3898.675701210793, 3830.502137630971, 3763.689256095772, 3698.2098343295606, 3634.037197034234, 3571.145204812779, 3509.508243320251, 3449.101212637378, 3389.8995168621464, 3331.8790539147503, 3275.016205551479, 3219.2878275831085, 3164.67124029357, 3111.144219054663, 3058.6849851327397, 3007.272196683334, 2956.884939929831, 2907.502720522319, 2859.1054550728772, 2811.6734628636304, 2765.1874577239596, 2719.628540073364, 2674.9781891265334, 2631.218255257245, 2588.330952517798, 2546.29885131078, 2505.104871209959, 2464.7322739272718, 2425.164656422827, 2386.3859441550126, 2348.3803844677773, 2311.1325401122685, 2274.6272829000472, 2238.849787485161, 2203.7855252724294, 2169.4202584493264, 2135.740034138915, 2102.731178671352, 2070.380291971514, 2038.6742420603532, 2007.6001596676595, 1977.1454329539165, 1947.2977023390386, 1918.0448554357743, 1889.3750220856302, 1861.2765694952304, 1833.7380974710309, 1806.7484337503881, 1780.2966294270072, 1754.3719544688304, 1728.9638933264819, 1704.0621406304167, 1679.6565969749563, 1655.737364787442, 1632.2947442807592, 1609.3192294875444, 1586.8015043743894, 1564.7324390344274, 1543.103085956696, 1521.9046763707145, 1501.1286166647337, 1480.76648487618, 1460.8100272527968, 1441.2511548830678, 1422.0819403944931, 1403.294614718361, 1384.8815639196362, 1366.8353260906727, 1349.1485883074192, 1331.8141836468862, 1314.825088264596, 1298.1744185308244, 1281.8554282244295, 1265.8615057830984, 1250.1861716088724, 1234.8230754278345, 1219.7659937028438, 1205.0088270982724, 1190.5455979956573, 1176.370448059266, 1162.4776358505442, 1148.8615344904729, 1135.5166293688555, 1122.437515899583, 1109.6188973209664, 1097.0555825402034, 1084.7424840210965, 1072.6746157141563, 1060.847091028219, 1049.2551208427546, 1037.8940115600326, 1026.7591631963503, 1015.846067511526, 1005.1503061758942, 994.6675489740443, 984.3935520445539, 974.3241561550045, 964.4552850115575, 954.7829436023975, 945.3032165743658, 936.0122666421063, 926.9063330290757, 917.9817299397752, 909.2348450625742, 900.66213810251, 892.2601393434612, 884.0254482391065, 875.9547320320814, 868.0447244007761, 860.292224133213, 852.6940938274606, 845.2472586180488, 837.9487049278656, 830.7954792450216, 823.784686924183, 816.9134910118777, 810.1791110952945, 803.5788221741076, 797.1099535548566, 790.7698877674344, 784.556059503 ...

# %%
# form the output given by our predictions of w and b

# plot the cost resulted, which is in our cost hist array

fig, (ax1, ax2) = plt.subplots(1,2, constrained_layout=True, figsize=(15,5)) # create 2 pictures in the same row to show how fast does the cost decrease
ax1.plot(cost_history)
ax1.set_title("Cost vs iterations")
ax1.set_xlabel("Iteration step")
ax1.set_ylabel("Cost")

ax2.plot(np.arange(len(cost_history[200:])), cost_history[200:])
ax2.set_title("Cost vs iterations")
ax2.set_xlabel("Iteration step")
ax2.set_ylabel("Cost")

plt.show()

# %%
# prepare the predicted output for plotting
m = X.shape[0]
yp = np.zeros(m)
for i in range(m):
  yp[i] = np.dot(X[i], w) + b

X_features=["feature 1", "feature 2", "feature 3"]
# plot predict
fig, ax = plt.subplots(1,X.shape[1], figsize=(12,3), sharey=True)
for i in range(len(ax)):
  ax[i].scatter( X[:,i], y, color="blue", label= 'target')
  ax[i].scatter( X[:,i], yp, color='red', label='predict')
  ax[i].set_xlabel(X_features[i])
ax[0].set_ylabel("Price")
ax[0].legend()
plt.show()
