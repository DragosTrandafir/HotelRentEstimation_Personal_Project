# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def compute_cost_linear_regression(X, y, w, b, lambda_l=1):
    '''
    Description: computes the cost for regularized linear regression
    ( the term with the numerator lambda helps to minimize the size of the parameters 
    (w1, w2,...),
    but I use the version where b is not regularized )
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: total_cost - real number - the cost of our calculations, which will help
    later to build a better model
    '''
    m = X.shape[0] # number of input data examples
    n = X.shape[1] # number of features of each example

    cost = 0
    for i in range(m):
       f_wb = np.dot(X[i],w)+b # the formula of linear regression model
       cost+= (f_wb-y[i])**2 
    cost = cost/(2*m)    # until here, we just applied the formula of the cost without regularization

    # the regularization part
    cost_r = 0
    for j in range(n):
        cost_r+= w[j]**2
    cost_r = (lambda_l/(2*m))* cost_r

    # adding the 2 costs
    total_cost = cost + cost_r
    return total_cost

# %%
# EXAMPLES PART - DOES NOT AFFECT OUR FINAL MODEL

np.random.seed(1) #running the cost function for some random input data (10 examples with 5 features each)
X1 = np.random.rand(10,5) 
y1 = np.array([0,1,0,0,1,1,1,1,0,1])
w1 = np.random.rand(5) - 0.5 
print(w1)
b1 = 0.5
lambda1 = 0.7
cost1 = compute_cost_linear_regression(X1, y1, w1, b1, lambda1)

print("Regularized cost example1:", cost1)


np.random.seed(1)  
X2 = np.random.rand(4,3) 
y2 = np.array([0,1,0,0])
w2 = np.random.rand(3) - 0.5
print(w2)
b2 = 0.5
lambda2 = 0.7
cost2 = compute_cost_linear_regression(X2, y2, w2, b2, lambda2)

print("Regularized cost example2:", cost2)
# Out:
# [-0.48063304  0.17883553 -0.28837188 -0.23445334 -0.00842684]
# Regularized cost example1: 0.236003117924045
# [-0.29554775  0.37811744 -0.47261241]
# Regularized cost example2: 0.1567201382524095

# %%
for i in range (X1.shape[1]):
    plt.scatter(X1[i,0], y1[i], marker='x', color='red') # use a scatter plot to display the data considering only the first feature of each example
#add a title & set x and y label
plt.title("Input vs Target")
plt.xlabel("input data")
plt.ylabel("target values")
plt.show()
# EXAMPLES PART - DOES NOT AFFECT OUR FINAL MODEL

# %%
def compute_gradient(X, y, w, b, lambda_l=1):
    '''
    Description: computes the partial derivative of the w vector and b scalar used in the gradient descent algorithm 
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: dj_dw - n array (size of w) and dj_db - scalar
    '''
    m = X.shape[0]
    n = X.shape[1]

    dj_dw = np.zeros((n,)) # null vector of n size
    dj_db = 0
    
    for i in range(m):
        f_wb = np.dot(X[i],w)+b
        aux = (f_wb - y[i])
        dj_db += aux # forming the derivative of b 

        # forming the gradient of w - unregularized part for now
        for j in range(n):
            dj_dw[j] += aux* X[i,j]

    dj_dw /= m
    dj_db /= m

    #now add the regularization part for the w feature vector
    for j in range(n):
        dj_dw[j] += (lambda_l/m) * w[j]

    return dj_db, dj_dw

# %% [raw]
# We have 20 room rent examples with price/ night in Cluj-Napoca - OUTPUT
# Each room has 4 features:
#  - number of stars on reviews : 0-5
#  - room capacity                                  - INPUT
#  - distance from the city center
#  - room area

# %%
# this is where HOTEL RENT PREDICTION MODEL data is taken as input

X = np.array([])
y = np.array([0.7,1,0,1,0.45,1,0,1,0,1,1,0.2,1,0,0,1,0,1,0.3,0])

# first, let us see if the gradient - partial derivative function - works and see its result applied on our data
w = np.random.rand(X.shape[1])
b = 0.5
lambda_m = 0.7
dj_db_m, dj_dw_m = compute_gradient(X, y, w, b, lambda_m)

print(f"dj_db: {dj_db_m}")
print(f"dj_dw: {dj_dw_m}")

# %%
def gradient_descent(X, y, w, b, compute_cost_linear_regression, compute_gradient, alpha, iterations):
    '''
    Descriptions: performs batch gradient descent to learn w vector and b parameter, using learning rate alpha and number of iterations
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    compute_cost_linear_regression, compute_gradient : functions to compute cost & gradient
                    alpha : learning rate
                    iterations: number of iterations
    Postconditons: w , b - updated values of parameters of the model & hist - array to store cost and w at every iteration
    '''
    hist = []
    for i in range(iterations):
        # calculate gradient for our parameters
        dj_db, dj_dw = compute_gradient(X, y, w, b)

        # update parameters using the learning rate
        w -= alpha* dj_dw
        b -= alpha* dj_db

        # save cost at every iteration if we do not have too many iterations (avoid resource exhaustion)
        if i<100000:
            hist.append(compute_cost_linear_regression(X, y, w, b))

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(iterations/ 10) == 0:
            print(f"Iteration {i:4d}: Cost {hist[-1]:8.2f}   ")

    return w, b, hist

# %%
# apply z-score normalization to bring our input data in the same range, so our model will perform faster and better

def zscore_normalize_features(X): 
    # description: computes  X, zcore normalized by column
    # pre: X - mxn array
    # post: X_norm : normalized data 

    # find the mean of each feature, by columns
    mu = np.mean(X, axis = 0) # nD array
    # find the standard deviation of each column
    sigma = np.std(X, axis=0) # nD array
    # apply the formula of the z-score normalization
    X_norm = (X - mu) / sigma      

    return X_norm

# %%
w_in= np.zeros((X.shape[1],))
b_in= 0

iterations=500
alpha=0.01

X_norm = zscore_normalize_features(X)
w,b,cost_history=gradient_descent(X_norm, y, w_in, b_in, compute_cost_linear_regression, compute_gradient, alpha, iterations)

print("w,b found by gradient descent:", w, b)
print(f"Cost history: {cost_history}")
# Out:
# Iteration    0: Cost     0.24
# Iteration   50: Cost     0.14
# Iteration  100: Cost     0.10
# Iteration  150: Cost     0.09
# Iteration  200: Cost     0.08
# Iteration  250: Cost     0.08
# Iteration  300: Cost     0.08
# Iteration  350: Cost     0.08
# Iteration  400: Cost     0.08
# Iteration  450: Cost     0.08
# w,b found by gradient descent: [-0.03568323  0.06444411 -0.14792262  0.09607816] 0.529001217779914
# Cost history: [0.24210181828846553, 0.23871464622966748, 0.23539938672704694, 0.23215447836391448, 0.22897839457992716, 0.22586964286726702, 0.22282676398602966, 0.21984833119834954, 0.21693294952079564, 0.2140792549945865, 0.2112859139731834, 0.2085516224268328, 0.20587510526363995, 0.20325511566676457, 0.20069043444734405, 0.19817986941275412, 0.19572225474983185, 0.1933164504226928, 0.19096134158478395, 0.18865583800482316, 0.18639887350628542, 0.1841894054201041, 0.18202641405026332, 0.1799089021519682, 0.17783589442208333, 0.17580643700154336, 0.17381959698944063, 0.17187446196850917, 0.16997013954172463, 0.1681057568797518, 0.16628046027897642, 0.1644934147298639, 0.16274380349539472, 0.1610308276993331, 0.15935370592409076, 0.1577116738179539, 0.15610398371144735, 0.1545299042426155, 0.15298871999100494, 0.15147973112014024, 0.15000225302828685, 0.1485556160073037, 0.14713916490939002, 0.14575225882153786, 0.14439427074750497, 0.1430645872971285, 0.14176260838280355, 0.14048774692295532, 0.13923942855233834, 0.13801709133899936, 0.13682018550774508, 0.1356481731699601, 0.13450052805962465, 0.13337673527538252, 0.13227629102851812, 0.13119870239670117, 0.1301434870833622, 0.1291101731825656, 0.12809829894925084, 0.12710741257471386, 0.12613707196720575, 0.12518684453752743, 0.12425630698950273, 0.123345045115215, 0.1224526535948952, 0.12157873580135162, 0.12072290360883527, 0.11988477720623633, 0.11906398491451028, 0.11826016300823433, 0.11747295554119785, 0.11670201417593255, 0.11594699801708977, 0.11520757344857523, 0.11448341397435428, 0.11377420006284128, 0.1130796189947899, 0.11239936471460303, 0.11173313768498282, 0.11108064474484325, 0.11044159897040913, 0.10981571953942848, 0.10920273159842532, 0.10860236613292325, 0.10801435984057044, 0.1074384550070995, 0.10687439938505691, 0.10632194607523705, 0.10578085341076039, 0.10525088484373289, 0.10473180883442904, 0.10422339874293912, 0.10372543272322512, 0.10323769361952946, 0.10275996886508258, 0.10229205038305733, 0.10183373448971807, 0.10138482179971439, 0.10094511713347085, 0.10051442942662454, 0.1000925716414639, 0.09967936068032301, 0.09927461730088709, 0.0988781660333654, 0.0984898350994895, 0.09810945633329501, 0.09773686510364639, 0.09737190023846572, 0.09701440395062622, 0.09666422176547318, 0.09632120244993549, 0.09598519794319152, 0.09565606328885465, 0.09533365656864375, 0.09501783883750563, 0.09470847406015594, 0.09440542904900745, 0.09410857340345402, 0.09381777945047981, 0.09353292218656399, 0.09325387922085192, 0.0929805307195646, 0.09271275935161798, 0.09245045023542582, 0.09219349088685917, 0.09194177116833656, 0.09169518323901994, 0.09145362150609149, 0.09121698257708709, 0.09098516521326322, 0.09075807028397384, 0.09053560072203519, 0.09031766148005606, 0.09010415948771291, 0.08989500360994754, 0.08969010460606808, 0.08948937508973276, 0.08929272948979668, 0.08910008401200284, 0.08891135660149865, 0.08872646690615948, 0.08854533624070157, 0.08836788755156709, 0.08819404538256363, 0.08802373584124235, 0.08785688656599788, 0.0876934266938743, 0.08753328682906159, 0.08737639901206765, 0.08722269668955054, 0.08707211468479685, 0.08692458916883194, 0.08678005763214801, 0.08663845885703664, 0.08649973289051262, 0.08636382101781577, 0.08623066573647867, 0.08610021073094742, 0.08597240084774349, 0.0858471820711551, 0.08572450149944617, 0.08560430732157219, 0.0854865487943908, 0.08537117622035789, 0.08525814092569726, 0.08514739523903427, 0.08503889247048327, 0.08493258689117897, 0.08482843371324178, 0.08472638907016834, 0.08462640999763757, 0.08452845441472309, 0.08443248110550368, 0.08433844970106318, 0.08424632066187059, 0.08415605526053323, 0.08406761556491417, 0.08398096442160656, 0.08389606543975643, 0.08381288297522757, 0.08373138211509981, 0.0836515286624948, 0.08357328912172116, 0.0834966306837327, 0.0834215212118932, 0.08334792922804034, 0.08327582389884323, 0.08320517502244673, 0.08313595301539645, 0.08306812889983864, 0.08300167429098897, 0.082 ...

# %%
# form the output given by our predictions of w and b

# plot the cost resulted, which is in our cost hist array

fig, (ax1, ax2) = plt.subplots(1,2, constrained_layout=True, figsize=(15,5)) # create 2 pictures in the same row to show how fast does the cost decrease
ax1.plot(cost_history)
ax1.set_title("Cost vs iterations")
ax1.set_xlabel("Iteration step")
ax1.set_ylabel("Cost")

ax2.plot(np.arange(len(cost_history[200:])), cost_history[200:])
ax2.set_title("Cost vs iterations")
ax2.set_xlabel("Iteration step")
ax2.set_ylabel("Cost")

plt.show()

# %%
# prepare the predicted output for plotting
m = X.shape[0]
yp = np.zeros(m)
for i in range(m):
  yp[i] = np.dot(X[i], w) + b

X_features=["feature 1", "feature 2", "feature 3", "feature 4"]
# plot predict
fig, ax = plt.subplots(1,X.shape[1], figsize=(12,3), sharey=True)
for i in range(len(ax)):
  ax[i].scatter( X[:,i], y, color="blue", label= 'target')
  ax[i].scatter( X[:,i], yp, color='red', label='predict')
  ax[i].set_xlabel(X_features[i])
ax[0].set_ylabel("Price")
ax[0].legend()
plt.show()
