# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def compute_cost_linear_regression(X, y, w, b, lambda_l=1):
    '''
    Description: computes the cost for regularized linear regression
    ( the term with the numerator lambda helps to minimize the size of the parameters 
    (w1, w2,...),
    but I use the version where b is not regularized )
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: total_cost - real number - the cost of our calculations, which will help
    later to build a better model
    '''
    m = X.shape[0] # number of input data examples
    n = X.shape[1] # number of features of each example

    cost = 0
    for i in range(m):
       f_wb = np.dot(X[i],w)+b # the formula of linear regression model
       cost+= (f_wb-y[i])**2 
    cost = cost/(2*m)    # until here, we just applied the formula of the cost without regularization

    # the regularization part
    cost_r = 0
    for j in range(n):
        cost_r+= w[j]**2
    cost_r = (lambda_l/(2*m))* cost_r

    # adding the 2 costs
    total_cost = cost + cost_r
    return total_cost

# %%
np.random.seed(1) #running the cost function for some random input data (10 examples with 5 features each)
X1 = np.random.rand(10,5) 
y1 = np.array([0,1,0,0,1,1,1,1,0,1])
w1 = np.random.rand(5) - 0.5 
print(w1)
b1 = 0.5
lambda1 = 0.7
cost1 = compute_cost_linear_regression(X1, y1, w1, b1, lambda1)

print("Regularized cost example1:", cost1)


np.random.seed(1)  
X2 = np.random.rand(4,3) 
y2 = np.array([0,1,0,0])
w2 = np.random.rand(3) - 0.5
print(w2)
b2 = 0.5
lambda2 = 0.7
cost2 = compute_cost_linear_regression(X2, y2, w2, b2, lambda2)

print("Regularized cost example2:", cost2)
# Out:
# [-0.48063304  0.17883553 -0.28837188 -0.23445334 -0.00842684]
# Regularized cost example1: 0.236003117924045
# [-0.29554775  0.37811744 -0.47261241]
# Regularized cost example2: 0.1567201382524095

# %%
def compute_gradient(X, y, w, b, lambda_l=1):
    '''
    Description: computes the partial derivative of the w vector and b scalar used in the gradient descent algorithm 
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: dj_dw - n array (size of w) and dj_db - scalar
    '''
    m = X.shape[0]
    n = X.shape[1]

    dj_dw = np.zeros((n,)) # null vector of n size
    dj_db = 0
    
    for i in range(m):
        f_wb = np.dot(X[i],w)+b
        aux = (f_wb - y[i])
        dj_db += aux # forming the derivative of b 

        # forming the gradient of w - unregularized part for now
        for j in range(n):
            dj_dw[j] += aux* X[i,j]

    dj_dw /= m
    dj_db /= m

    #now add the regularization part for the w feature vector
    for j in range(n):
        dj_dw[j] += (lambda_l/m) * w[j]

    return dj_db, dj_dw

# %%
# testing the gradient function to see the results
np.random.seed(1)
X1 = np.random.rand(20,4)
y1 = np.array([0.7,1,0,1,0.45,1,0,1,0,1,1,0.2,1,0,0,1,0,1,0.3,0])
w1 = np.random.rand(X1.shape[1])
b1 = 0.5
lambda1 = 0.7
dj_db1, dj_dw1 = compute_gradient(X1, y1, w1, b1, lambda1)

print(f"dj_db: {dj_db1}")
print(f"dj_dw: {dj_dw1}")
# Out:
# dj_db: 1.1794843967613495
# dj_dw: [0.71501008 0.70255245 0.59429547 0.53291232]

# %%
for i in range (20):
    plt.scatter(X1[i,0], y1[i], marker='x', color='red') # use a scatter plot to display the data considering only the first feature of each example
#add a title & set x and y label
plt.title("Input vs Target")
plt.xlabel("input data")
plt.ylabel("target values")
plt.show()

# %%
def gradient_descent(X, y, w, b, compute_cost_linear_regression, compute_gradient, alpha, iterations):
    '''
    Descriptions: performs batch gradient descent to learn w vector and b parameter, using learning rate alpha and number of iterations
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    compute_cost_linear_regression, compute_gradient : functions to compute cost & gradient
                    alpha : learning rate
                    iterations: number of iterations
    Postconditons: w , b - updated values of parameters of the model & hist - array to store cost and w at every iteration
    '''
    hist = []
    for i in range(iterations):
        # calculate gradient for our parameters
        dj_db, dj_dw = compute_gradient(X, y, w, b)

        # update parameters using the learning rate
        w -= alpha* dj_dw
        b -= alpha* dj_db

        # save cost at every iteration if we do not have too many iterations (avoid resource exhaustion)
        if i<100000:
            hist.append(compute_cost_linear_regression(X, y, w, b))

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(iterations/ 10) == 0:
            print(f"Iteration {i:4d}: Cost {hist[-1]:8.2f}   ")

    return w, b, hist

# %%
w_in= np.zeros((X1.shape[1],))
b_in= 0

iterations=500
alpha=0.01

w,b,cost_history=gradient_descent(X1, y1, w1, b1, compute_cost_linear_regression, compute_gradient, alpha, iterations)

print("w,b found by gradient descent:", w, b)
print(f"Cost history: {cost_history}")
# Out:
# Iteration    0: Cost     0.93
# Iteration   50: Cost     0.27
# Iteration  100: Cost     0.17
# Iteration  150: Cost     0.15
# Iteration  200: Cost     0.14
# Iteration  250: Cost     0.13
# Iteration  300: Cost     0.13
# Iteration  350: Cost     0.12
# Iteration  400: Cost     0.12
# Iteration  450: Cost     0.12
# w,b found by gradient descent: [0.2501285  0.32382572 0.10864546 0.1981143 ] 0.07007470256028978
# Cost history: [0.9299830407939734, 0.9006094671760442, 0.8723642652637225, 0.845203786448187, 0.8190860714251222, 0.7939707848121567, 0.7698191522968599, 0.7465939002173637, 0.724259197481448, 0.7027805997335914, 0.6821249956829751, 0.6622605555088041, 0.6431566812625488, 0.624783959189812, 0.6071141138975319, 0.590119964295091, 0.5737753812406812, 0.5580552468269195, 0.5429354152422721, 0.5283926751472948, 0.5144047135070622, 0.500950080823424, 0.4880081577129095, 0.4755591227781995, 0.46358392172309904, 0.4520642376628817, 0.440982462583741, 0.43032166990687315, 0.4200655881144377, 0.4101985753962977, 0.4007055952780307, 0.39157219319223163, 0.38278447395659776, 0.3743290801237015, 0.36619317116871114, 0.35836440348262943, 0.3508309111398713, 0.34358128741021354, 0.3366045669863023, 0.3298902088990291, 0.32342808009414536, 0.31720843964452866, 0.3112219235734955, 0.30545953026551154, 0.2999126064415645, 0.2945728336773449, 0.28943221544322595, 0.2844830646458477, 0.2797179916518899, 0.2751298927753716, 0.2707119392105382, 0.26645756639308804, 0.2623604637731618, 0.25841456498415627, 0.25461403839204494, 0.2509532780104748, 0.24742689476748614, 0.24402970811024277, 0.24075673793469315, 0.23760319682758455, 0.23456448260874074, 0.2316361711619841, 0.2288140095435273, 0.22609390935709792, 0.22347194038547133, 0.22094432446848725, 0.2185074296180121, 0.2161577643606737, 0.2138919722995548, 0.21170682688637016, 0.20959922639597978, 0.20756618909540908, 0.20560484859984504, 0.20371244940837474, 0.20188634261250693, 0.20012398177079088, 0.19842291894310257, 0.19678080087842015, 0.19519536535014667, 0.1936644376332693, 0.19218592711786692, 0.1907578240536868, 0.1893781964207198, 0.1880451869208951, 0.1867570100862081, 0.18551194949877503, 0.1843083551184817, 0.1831446407140624, 0.1820192813936055, 0.1809308112306382, 0.1798778209820905, 0.17885895589458228, 0.17787291359561572, 0.17691844206638618, 0.1759943376930527, 0.17509944339343203, 0.17423264681619613, 0.17339287860976754, 0.17257911075821486, 0.17179035498155515, 0.17102566119797077, 0.17028411604554333, 0.16956484146120307, 0.1688669933146766, 0.16818976009530748, 0.16753236164969987, 0.16689404796822144, 0.16627409801847176, 0.1656718186239004, 0.16508654338582604, 0.16451763164717775, 0.1639644674963423, 0.16342645880956713, 0.16290303633042477, 0.16239365278490558, 0.16189778203075955, 0.1614149182397612, 0.160944575111624, 0.16048628511833832, 0.16003959877775695, 0.15960408395529446, 0.15917932519265365, 0.15876492306253237, 0.15836049354830514, 0.1579656674477134, 0.15758008979963448, 0.1572034193330368, 0.1568353279372623, 0.15647550015281012, 0.15612363268182922, 0.15577943391755553, 0.1554426234919628, 0.15511293184091862, 0.15479009978617247, 0.15447387813352023, 0.15416402728652204, 0.15386031687516974, 0.1535625253989264, 0.15327043988358086, 0.15298385555138316, 0.15270257550394634, 0.1524264104174213, 0.1521551782494687, 0.15188870395757167, 0.1516268192282514, 0.15136936221676178, 0.15111617729685894, 0.15086711482025528, 0.15062203088538298, 0.15038078711510716, 0.15014325044304183, 0.14990929290813593, 0.1496787914572092, 0.14945162775513027, 0.14922768800234168, 0.14900686275944616, 0.14878904677858257, 0.14857413884132725, 0.14836204160286928, 0.14815266144221606, 0.14794590831819626, 0.14774169563103562, 0.14753994008929, 0.14734056158192832, 0.14714348305536562, 0.14694863039525552, 0.146755932312857, 0.14656532023579943, 0.14637672820307424, 0.14619009276409106, 0.1460053528816404, 0.1458224498386111, 0.14564132714831843, 0.14546193046830244, 0.14528420751746177, 0.14510810799639481, 0.14493358351082342, 0.14476058749798018, 0.14458907515584427, 0.14441900337511582, 0.14425033067382304, 0.14408301713445915, 0.14391702434355347, 0.14375231533357907, 0.1435888545271104, 0.1434266076831402, 0.143265541845475, 0.14310562529312687, 0.14294682749262524, 0.14278911905217392, 0.14263247167758183, 0.14247685812989958, 0.14232225218469494, 0.14216862859290413, 0 ...

# %%
# form the output given by our predictions of w and b

# plot the cost resulted, which is in our cost hist array

fig, (ax1, ax2) = plt.subplots(1,2, constrained_layout=True, figsize=(15,5)) # create 2 pictures in the same row to show how fast does the cost decrease
ax1.plot(cost_history)
ax1.set_title("Cost vs iterations")
ax1.set_xlabel("Iteration step")
ax1.set_ylabel("Cost")

ax2.plot(np.arange(len(cost_history[200:])), cost_history[200:])
ax2.set_title("Cost vs iterations")
ax2.set_xlabel("Iteration step")
ax2.set_ylabel("Cost")

plt.show()

# %%
#def zscore_normalize_features(X) - TODO

# %%
# prepare the predicted output for plotting
m = X1.shape[0]
yp = np.zeros(m)
for i in range(m):
  yp[i] = np.dot(X1[i], w) + b

X_features=["feature 1", "feature 2", "feature 3", "feature 4"]
# plot predict
fig, ax = plt.subplots(1,X1.shape[1], figsize=(12,3), sharey=True)
for i in range(len(ax)):
  ax[i].scatter( X1[:,i], y1, color="blue", label= 'target')
  ax[i].scatter( X1[:,i], yp, color='red', label='predict')
  ax[i].set_xlabel(X_features[i])
ax[0].set_ylabel("Price")
ax[0].legend()
plt.show()
