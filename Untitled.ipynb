# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def compute_cost_linear_regression(X, y, w, b, lambda_l=1):
    '''
    Description: computes the cost for regularized linear regression
    ( the term with the numerator lambda helps to minimize the size of the parameters 
    (w1, w2,...),
    but I use the version where b is not regularized )
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: total_cost - real number - the cost of our calculations, which will help
    later to build a better model
    '''
    m = X.shape[0] # number of input data examples
    n = X.shape[1] # number of features of each example

    cost = 0
    for i in range(m):
       f_wb = np.dot(X[i],w)+b # the formula of linear regression model
       cost+= (f_wb-y[i])**2 
    cost = cost/(2*m)    # until here, we just applied the formula of the cost without regularization

    # the regularization part
    cost_r = 0
    for j in range(n):
        cost_r+= w[j]**2
    cost_r = (lambda_l/(2*m))* cost_r

    # adding the 2 costs
    total_cost = cost + cost_r
    return total_cost

# %%
np.random.seed(1) #running the cost function for some random input data (10 examples with 5 features each)
X1 = np.random.rand(10,5) 
y1 = np.array([0,1,0,0,1,1,1,1,0,1])
w1 = np.random.rand(5) - 0.5 
print(w1)
b1 = 0.5
lambda1 = 0.7
cost1 = compute_cost_linear_regression(X1, y1, w1, b1, lambda1)

print("Regularized cost example1:", cost1)


np.random.seed(1)  
X2 = np.random.rand(4,3) 
y2 = np.array([0,1,0,0])
w2 = np.random.rand(3) - 0.5
print(w2)
b2 = 0.5
lambda2 = 0.7
cost2 = compute_cost_linear_regression(X2, y2, w2, b2, lambda2)

print("Regularized cost example2:", cost2)
# Out:
# [-0.48063304  0.17883553 -0.28837188 -0.23445334 -0.00842684]
# Regularized cost example1: 0.236003117924045
# [-0.29554775  0.37811744 -0.47261241]
# Regularized cost example2: 0.1567201382524095

# %%
def compute_gradient(X, y, w, b, lambda_l=1):
    '''
    Description: computes the partial derivative of the w vector and b scalar used in the gradient descent algorithm 
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: dj_dw - n array (size of w) and dj_db - scalar
    '''
    m = X.shape[0]
    n = X.shape[1]

    dj_dw = np.zeros((n,)) # null vector of n size
    dj_db = 0
    
    for i in range(m):
        f_wb = np.dot(X[i],w)+b
        aux = (f_wb - y[i])
        dj_db += aux # forming the derivative of b 

        # forming the gradient of w - unregularized part for now
        for j in range(n):
            dj_dw[j] += aux* X[i,j]

    dj_dw /= m
    dj_db /= m

    #now add the regularization part for the w feature vector
    for j in range(n):
        dj_dw[j] += (lambda_l/m) * w[j]

    return dj_db, dj_dw

# %%
# testing the gradient function to see the results
np.random.seed(1)
X1 = np.random.rand(20,4)
y1 = np.array([0.7,1,0,1,0.45,1,0,1,0,1,1,0.2,1,0,0,1,0,1,0.3,0])
w1 = np.random.rand(X1.shape[1])
b1 = 0.5
lambda1 = 0.7
dj_db1, dj_dw1 = compute_gradient(X1, y1, w1, b1, lambda1)

print(f"dj_db: {dj_db1}")
print(f"dj_dw: {dj_dw1}")
# Out:
# dj_db: 1.1794843967613495
# dj_dw: [0.71501008 0.70255245 0.59429547 0.53291232]

# %%
for i in range (20):
    plt.scatter(X1[i,0], y1[i], marker='x', color='red') # use a scatter plot to display the data considering only the first feature of each example
#add a title & set x and y label
plt.title("Input vs Target")
plt.xlabel("input data")
plt.ylabel("target values")
plt.show()

# %%
def gradient_descent(X, y, w, b, compute_cost_linear_regression, compute_gradient, alpha, iterations):
    '''
    Descriptions: performs batch gradient descent to learn w vector and b parameter, using learning rate alpha and number of iterations
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    compute_cost_linear_regression, compute_gradient : functions to compute cost & gradient
                    alpha : learning rate
                    iterations: number of iterations
    Postconditons: w , b - updated values of parameters of the model & hist - array to store cost and w at every iteration
    '''
    hist = []
    for i in range(iterations):
        # calculate gradient for our parameters
        dj_db, dj_dw = compute_gradient(X, y, w, b)

        # update parameters using the learning rate
        w -= alpha* dj_dw
        b -= alpha* dj_db

        # save cost at every iteration if we do not have too many iterations (avoid resource exhaustion)
        if i<100000:
            hist.append(compute_cost_linear_regression(X, y, w, b))

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(iterations/ 10) == 0:
            print(f"Iteration {i:4d}: Cost {hist[-1]:8.2f}   ")

    return w, b, hist

# %%
w_in= np.zeros((X1.shape[1],))
b_in= 0

iterations=100
alpha=0.01

w,b,cost_history=gradient_descent(X1, y1, w1, b1, compute_cost_linear_regression, compute_gradient, alpha, iterations)

print("w,b found by gradient descent:", w, b)
print(f"Cost history: {cost_history}")
# Out:
# Iteration    0: Cost     0.09
# Iteration   10: Cost     0.09
# Iteration   20: Cost     0.09
# Iteration   30: Cost     0.09
# Iteration   40: Cost     0.09
# Iteration   50: Cost     0.09
# Iteration   60: Cost     0.09
# Iteration   70: Cost     0.09
# Iteration   80: Cost     0.09
# Iteration   90: Cost     0.09
# w,b found by gradient descent: [-0.06212507  0.17041589 -0.36188417  0.23264351] 0.5005008838394743
# Cost history: [0.08703929586855749, 0.08703927804460906, 0.08703926090485409, 0.08703924442282246, 0.08703922857306867, 0.0870392133311319, 0.08703919867349807, 0.08703918457756324, 0.08703917102159818, 0.08703915798471476, 0.08703914544683322, 0.08703913338865095, 0.08703912179161238, 0.08703911063788015, 0.08703909991030721, 0.08703908959241013, 0.08703907966834348, 0.08703907012287504, 0.08703906094136217, 0.08703905210972886, 0.0870390436144439, 0.08703903544249982, 0.08703902758139254, 0.08703902001910184, 0.0870390127440728, 0.08703900574519768, 0.08703899901179858, 0.08703899253361091, 0.08703898630076733, 0.08703898030378235, 0.0870389745335376, 0.0870389689812676, 0.08703896363854613, 0.08703895849727308, 0.08703895354966172, 0.08703894878822686, 0.08703894420577278, 0.08703893979538242, 0.08703893555040634, 0.08703893146445242, 0.08703892753137593, 0.08703892374526999, 0.08703892010045625, 0.08703891659147614, 0.08703891321308234, 0.0870389099602306, 0.08703890682807189, 0.08703890381194483, 0.0870389009073684, 0.08703889811003503, 0.08703889541580379, 0.0870388928206941, 0.08703889032087934, 0.08703888791268101, 0.08703888559256293, 0.08703888335712581, 0.08703888120310183, 0.08703887912734971, 0.08703887712684967, 0.08703887519869884, 0.0870388733401066, 0.0870388715483904, 0.08703886982097145, 0.08703886815537075, 0.08703886654920523, 0.08703886500018403, 0.08703886350610496, 0.08703886206485101, 0.08703886067438708, 0.08703885933275689, 0.08703885803807974, 0.08703885678854778, 0.08703885558242311, 0.087038854418035, 0.08703885329377743, 0.08703885220810653, 0.08703885115953813, 0.08703885014664552, 0.08703884916805707, 0.08703884822245436, 0.08703884730856996, 0.08703884642518538, 0.0870388455711293, 0.08703884474527583, 0.08703884394654249, 0.08703884317388877, 0.0870388424263143, 0.08703884170285758, 0.08703884100259417, 0.08703884032463541, 0.08703883966812702, 0.08703883903224785, 0.08703883841620841, 0.08703883781924969, 0.08703883724064222, 0.08703883667968462, 0.08703883613570265, 0.08703883560804819, 0.08703883509609811, 0.08703883459925348]

# %%
# form the output given by our predictions of w and b
m = X1.shape[0]
predicted = np.zeros(m)

for i in range(m):
    predicted[i] = np.dot(X1[i],w)+b


#plot to see the accuracy of our linear regression with our target data considering the first coordinate (so as be able to plot in 2D)
for i in range (m):
    plt.scatter(X1[i,0], y1[i], marker='x', color='red') # use a scatter plot to display the data considering only the first feature of each example
    
#X1_plot = X1[:,0]
print(predicted)
print(y1)
plt.plot(X1_plot, predicted, color='blue')

#add a title & set x and y label
plt.title("Input vs Target")
plt.xlabel("input data")
plt.ylabel("target values")
plt.show()
# Out:
# [0.66764243 0.52010747 0.57538663 0.78351322 0.56506864 0.66340285
#  0.57682003 0.70197739 0.35487506 0.76798342 0.64869962 0.30991724
#  0.65569984 0.36712875 0.43937257 0.40976877 0.46829162 0.24683192
#  0.52399627 0.39933589]
# [0.7  1.   0.   1.   0.45 1.   0.   1.   0.   1.   1.   0.2  1.   0.
#  0.   1.   0.   1.   0.3  0.  ]
