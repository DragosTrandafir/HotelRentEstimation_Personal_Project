# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def compute_cost_linear_regression(X, y, w, b, lambda_l=1):
    '''
    Description: computes the cost for regularized linear regression
    ( the term with the numerator lambda helps to minimize the size of the parameters 
    (w1, w2,...),
    but I use the version where b is not regularized )
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: total_cost - real number - the cost of our calculations, which will help
    later to build a better model
    '''
    m = X.shape[0] # number of input data examples
    n = len(w) # number of features of each example

    cost = 0.
    for i in range(m):
       f_wb = np.dot(X[i],w)+b # the formula of linear regression model
       cost+= (f_wb-y[i])**2 
    cost = cost/(2*m)    # until here, we just applied the formula of the cost without regularization

    # the regularization part
    cost_r = 0
    for j in range(n):
        cost_r+= w[j]**2
    cost_r = (lambda_l/(2*m))* cost_r

    # adding the 2 costs
    total_cost = cost + cost_r
    return total_cost

# %%
# EXAMPLES PART - DOES NOT AFFECT OUR FINAL MODEL

np.random.seed(1) #running the cost function for some random input data (10 examples with 5 features each)
X1 = np.random.rand(10,5) 
y1 = np.array([0,1,0,0,1,1,1,1,0,1])
w1 = np.random.rand(5) - 0.5 
print(w1)
b1 = 0.5
lambda1 = 0.7
cost1 = compute_cost_linear_regression(X1, y1, w1, b1, lambda1)

print("Regularized cost example1:", cost1)


np.random.seed(1)  
X2 = np.random.rand(4,3) 
y2 = np.array([0,1,0,0])
w2 = np.random.rand(3) - 0.5
print(w2)
b2 = 0.5
lambda2 = 0.7
cost2 = compute_cost_linear_regression(X2, y2, w2, b2, lambda2)

print("Regularized cost example2:", cost2)
# Out:
# [-0.48063304  0.17883553 -0.28837188 -0.23445334 -0.00842684]
# Regularized cost example1: 0.236003117924045
# [-0.29554775  0.37811744 -0.47261241]
# Regularized cost example2: 0.1567201382524095

# %%
for i in range (X1.shape[1]):
    plt.scatter(X1[i,0], y1[i], marker='x', color='red') # use a scatter plot to display the data considering only the first feature of each example
#add a title & set x and y label
plt.title("Input vs Target")
plt.xlabel("input data")
plt.ylabel("target values")
plt.show()
# EXAMPLES PART - DOES NOT AFFECT OUR FINAL MODEL

# %%
def compute_gradient(X, y, w, b, lambda_l):
    '''
    Description: computes the partial derivative of the w vector and b scalar used in the gradient descent algorithm 
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    lambda_l - real number - quantifier for regularization
    Postconditons: dj_dw - n array (size of w) and dj_db - scalar
    '''
    m = X.shape[0]
    n = X.shape[1]

    dj_dw = np.zeros((n,)) # null vector of n size
    dj_db = 0.0
    
    for i in range(m):
        f_wb = np.dot(X[i],w)+b
        aux = (f_wb - y[i])
        dj_db += aux # forming the derivative of b 

        # forming the gradient of w - unregularized part for now
        for j in range(n):
            dj_dw[j] += aux* X[i,j]

    dj_dw /= m
    dj_db /= m

    #now add the regularization part for the w feature vector
    for j in range(n):
        dj_dw[j] += (lambda_l/m) * w[j]

    return dj_db, dj_dw

# %%
# this is where HOTEL RENT PREDICTION MODEL data is taken as input

'''
We have 20 room rent examples with price per person/ night in Cluj-Napoca                         - OUTPUT
Each room has 4 features:                                          
 - number of stars on reviews : 0-10                                                               - INPUT
 - distance from the city center (meters)
 - room area (meters^2)
 '''

X = np.array([[6.8,1900,17],
              [8.4,1900,16],
              [8.4,1900,20],
              [8.7,2300,30],
              [8.7,2300,36],
              [8.6,2300,20],
              [7.1,1400,16],  #7
             [8.8,2100,32],
              [8.7,2000,25],
              [7.7,1500,20],   #10
              [9,3300,15],
              [8.1,1800,22],
              [8.4,2200,25],
              [8.9,2300,30],   #14
              [8.5,2000,22],
              [7.9,1900,18],
              [8,2300,16],
              [8.1,2200,16],
              [8.6,2500,18],
              [8.3,2400,15]])
X_norm = zscore_normalize_features(X)
y = np.array([262,190,220,140,185,171,150,200 ,220 ,250     ,130 , #11 
              200,185,195 #14
              ,210, 250,    
              230,  220   ,160,150]) # it does matter whether the data is sorted or not

# first, let us see if the gradient - partial derivative function - works and see its result applied on our data
w = np.random.rand(X_norm.shape[1])
b = 0.5
lambda_m = 0.7
dj_db_m, dj_dw_m = compute_gradient(X_norm, y, w, b,  lambda_m)

print(f"dj_db: {dj_db_m}")
print(f"dj_dw: {dj_dw_m}")
# Out:
# dj_db: -195.39999999999998
# dj_dw: [18.32559268 20.26373122  3.29924752]

# %%
def gradient_descent(X, y, w, b, compute_cost_linear_regression, compute_gradient, alpha, iterations):
    '''
    Descriptions: performs batch gradient descent to learn w vector and b parameter, using learning rate alpha and number of iterations
    Preconditions: X - m x n matrix which contains our data 
                    y - m size array - target values
                    w - n size array - model parameters
                    b - real number - free term parameter
                    compute_cost_linear_regression, compute_gradient : functions to compute cost & gradient
                    alpha : learning rate
                    iterations: number of iterations
    Postconditons: w , b - updated values of parameters of the model & hist - array to store cost and w at every iteration
    '''
    hist = []
    for i in range(iterations):
        # calculate gradient for our parameters
        dj_db, dj_dw = compute_gradient(X, y, w, b,0.01)

        # update parameters using the learning rate
        w -= alpha* dj_dw
        b -= alpha* dj_db

        # save cost at every iteration if we do not have too many iterations (avoid resource exhaustion)
        if i<100000:
            hist.append(compute_cost_linear_regression(X, y, w, b))

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(iterations/ 10) == 0:
            print(f"Iteration {i:4d}: Cost {hist[-1]:8.2f}   ")

    return w, b, hist

# %%
# apply z-score normalization to bring our input data in the same range, so our model will perform faster and better

def zscore_normalize_features(X): 
    # description: computes  X, zcore normalized by column
    # pre: X - mxn array
    # post: X_norm : normalized data 

    # find the mean of each feature, by columns
    mu = np.mean(X, axis = 0) # nD array
    # find the standard deviation of each column
    sigma = np.std(X, axis=0) # nD array
    # apply the formula of the z-score normalization
    X_norm = (X - mu) / sigma      

    return X_norm

# %%
w_in= np.zeros((X_norm.shape[1],))
b_in= 0

iterations=1000
alpha=0.01 # 5.0e-7


w,b,cost_history=gradient_descent(X_norm, y, w_in, b_in, compute_cost_linear_regression, compute_gradient, alpha, iterations)

print("w,b found by gradient descent:", w, b)
print(f"Cost history: {cost_history}")
# Out:
# Iteration    0: Cost 19480.47
# Iteration  100: Cost  3006.51
# Iteration  200: Cost   816.67
# Iteration  300: Cost   523.97
# Iteration  400: Cost   484.86
# Iteration  500: Cost   479.66
# Iteration  600: Cost   478.97
# Iteration  700: Cost   478.89
# Iteration  800: Cost   478.88
# Iteration  900: Cost   478.88
# w,b found by gradient descent: [ -9.97667911 -13.03925683   2.6368624 ] 195.89154275263223
# Cost history: [19480.46981423268, 19099.76586786673, 18726.72903784278, 18361.20348895542, 18003.03660406933, 17652.078915880422, 17308.184040185803, 16971.20861062704, 16641.012214872226, 16317.457332203106, 16000.409272474564, 15689.736116414384, 15385.308657232128, 15087.000343506797, 14794.687223323488, 14508.247889630346, 14227.56342678742, 13952.517358280129, 13682.995595570437, 13418.886388059596, 13160.080274137064, 12906.47003329063, 12657.950639253566, 12414.419214165124, 12175.774983721338, 11941.919233293533, 11712.755264992718, 11488.188355658302, 11268.125715750315, 11052.476449124662, 10841.151513671579, 10634.063682797798, 10431.12750773349, 10232.259280645474, 10037.376998538632, 9846.400327927893, 9659.250570263592, 9475.850628093378, 9296.124971944308, 9119.999607909058, 8947.402045920715, 8778.261268700737, 8612.507701365363, 8450.073181675747, 8290.890930917722, 8134.895525397266, 7982.022868538113, 7832.210163568316, 7685.395886782757, 7541.519761369067, 7400.522731784543, 7262.3469386720635, 7126.935694303209, 6994.233458537101, 6864.185815283695, 6736.739449460614, 6611.842124432755, 6489.442659924159, 6369.490910392, 6251.937743852615, 6136.735021149808, 6023.835575655909, 5913.193193396222, 5804.762593587743, 5698.499409583243, 5594.360170211984, 5492.302281508566, 5392.284008821556, 5294.264459293785, 5198.20356470633, 5104.062064678434, 5011.8014902157165, 4921.384147599295, 4832.773102608496, 4745.932165070085, 4660.82587372705, 4577.419481420171, 4495.678940575684, 4415.570888992584, 4337.062635923227, 4260.122148440964, 4184.718038088784, 4110.819547803006, 4038.396539106212, 3967.419479563744, 3897.859430498186, 3829.6880349564344, 3762.877505924011, 3697.400614781417, 3633.230679997462, 3570.3415560545736, 3508.7076226012423, 3448.3037738267954, 3389.105408053903, 3331.088417544212, 3274.2291785126627, 3218.5045413461426, 3163.891821022185, 3110.3687877235484, 3057.913657644604, 3006.505083985501, 2956.1221481302473, 2906.7443510048206, 2858.351604611615, 2810.924223736534, 2764.4429178251426, 2718.888783024382, 2674.243294386399, 2630.488298231146, 2587.6060046644307, 2545.5789802482473, 2504.390140820187, 2464.022744458871, 2424.4603845923907, 2385.6869832467873, 2347.6867844316894, 2310.4443476602714, 2273.944541600775, 2238.1725378568667, 2203.113804874189, 2168.7541019705054, 2135.079473486883, 2102.076243057451, 2069.731007995266, 2038.0306337919187, 2006.962248728545, 1976.5132385959441, 1946.6712415215732, 1917.4241429012318, 1888.7600704332713, 1860.6673892532533, 1833.1346971669866, 1806.1508199799196, 1779.704806920942, 1753.7859261586434, 1728.3836604081473, 1703.4877026266645, 1679.087951795965, 1655.1745087899797, 1631.7376723258071, 1608.7679349964121, 1586.255979383359, 1564.1926742479425, 1542.5690707991248, 1521.376399036711, 1500.6060641682204, 1480.2496430979784, 1460.2988809869305, 1440.7456878817693, 1421.5821354119314, 1402.8004535531193, 1384.3930274559707, 1366.3523943385662, 1348.6712404414682, 1331.3423980440373, 1314.3588425407577, 1297.7136895763872, 1281.4001922387079, 1265.4117383077282, 1249.7418475601808, 1234.384169128211, 1219.3324789111412, 1204.5806770392421, 1190.1227853884684, 1175.9529451451076, 1162.0654144193488, 1148.4545659067746, 1135.1148845968096, 1122.0409655271656, 1109.227511583376, 1096.6693313424855, 1084.3613369600107, 1072.2985420993086, 1060.4760599024735, 1048.889101001951, 1037.5329715720218, 1026.403071419369, 1015.4948921119326, 1004.8040151452772, 994.3261101457235, 984.0569331094919, 973.9923246771458, 964.1282084426081, 954.460589296067, 944.9855518000793, 935.6992585982097, 926.5979488555428, 917.6779367304371, 908.9356098768792, 900.3674279768308, 891.9699213019657, 883.7396893041985, 875.6733992344316, 867.7677847889515, 860.0196447829164, 852.4258418503964, 844.9833011704214, 837.6890092185259, 830.5400125432716, 823.5334165672487, 816.666384412059, 809.9361357468073, 803.3399456596225, 796.8751435517479, 790.5391120537474, 784.3 ...

# %%
# form the output given by our predictions of w and b

# plot the cost resulted, which is in our cost hist array

fig, (ax1, ax2) = plt.subplots(1,2, constrained_layout=True, figsize=(15,5)) # create 2 pictures in the same row to show how fast does the cost decrease
ax1.plot(cost_history)
ax1.set_title("Cost vs iterations")
ax1.set_xlabel("Iteration step")
ax1.set_ylabel("Cost")

ax2.plot(np.arange(len(cost_history[200:])), cost_history[200:])
ax2.set_title("Cost vs iterations")
ax2.set_xlabel("Iteration step")
ax2.set_ylabel("Cost")

plt.show()

# %%
# prepare the predicted output for plotting
m = X_norm.shape[0]
yp = np.zeros(m)
for i in range(m):
  yp[i] = np.dot(X_norm[i], w) + b

X_features=["feature 1", "feature 2", "feature 3"]
# plot predict
fig, ax = plt.subplots(1,X.shape[1], figsize=(12,3), sharey=True)
for i in range(len(ax)):
  ax[i].scatter( X[:,i], y, color="blue", label= 'target')
  ax[i].scatter( X[:,i], yp, color='red', label='predict')
  ax[i].set_xlabel(X_features[i])
ax[0].set_ylabel("Price")
ax[0].legend()
plt.show()
